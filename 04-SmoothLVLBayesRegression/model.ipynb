# %%
import math
import numpy as np
import matplotlib.pylab as plt
np.set_printoptions(precision=2)
import scipy.io as sio

# %% [markdown]
# Načtení dat

# %%
X = sio.loadmat("../dataCustom.mat")["X"]
y = sio.loadmat("../dataCustom.mat")["y"]
beta_true = sio.loadmat("../dataCustom.mat")["beta_true"]

# %% [markdown]
# Hledání parametrů

# %%
# Import modelu z ModelsCollection
import sys
sys.path.append('..')
from ModelsCollection import bayesLVLRegression,bayesLVLPositiveRegression

# %% [markdown]
# # Vykreslení

# %% [markdown]
# ## l0 = 0, bez podmínky pozitivity

# %%
l0 = 0
betaHat, sigmaBeta, hist_omega = bayesLVLRegression(X,y,l0=l0)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(beta_true,color='red',linestyle='dashed')
axs[0].plot(betaHat,color = 'blue')
unc_1 = np.matrix(betaHat) + np.matrix(np.sqrt(np.diag(sigmaBeta))).T
unc_2 = np.matrix(betaHat) - np.matrix(np.sqrt(np.diag(sigmaBeta))).T
axs[0].plot(unc_1,color = 'grey',linestyle='dashed')
axs[0].plot(unc_2,color = 'grey',linestyle='dashed')
axs[0].set_title("Sparse and Smooth LVLt Regression")

axs[1].plot(hist_omega)
axs[1].set_title("OmegaHat development")
plt.show()

# %%
# betaHat zaokrouhlená na 3 desetinná místa pro účely porovnání s modelem s obecnou maticí L
print(np.round(betaHat,3))
# Out:
# [[0.1 ]
#  [0.19]
#  [1.07]
#  [1.01]
#  [0.02]
#  [0.02]
#  [0.01]
#  [0.01]
#  [0.01]
#  [1.03]
#  [1.02]
#  [0.01]
#  [0.01]
#  [1.01]
#  [0.03]]

# %% [markdown]
# ## l0 = -1, bez podmínky pozitivity

# %%
l0 = -1
betaHat, sigmaBeta, hist_omega = bayesLVLRegression(X,y,l0=l0)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(beta_true,color='red',linestyle='dashed')
axs[0].plot(betaHat,color = 'blue')
unc_1 = np.matrix(betaHat) + np.matrix(np.sqrt(np.diag(sigmaBeta))).T
unc_2 = np.matrix(betaHat) - np.matrix(np.sqrt(np.diag(sigmaBeta))).T
axs[0].plot(unc_1,color = 'grey',linestyle='dashed')
axs[0].plot(unc_2,color = 'grey',linestyle='dashed')
axs[0].set_title("Sparse and Smooth LVLt Regression")

axs[1].plot(hist_omega)
axs[1].set_title("OmegaHat development")
plt.show()

# %% [markdown]
# ## l0 = 0, positive

# %%
l0 = 0
betaHat, sigmaBeta, hist_omega = bayesLVLPositiveRegression(X,y,l0=l0)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(beta_true,color='red',linestyle='dashed')
axs[0].plot(betaHat,color = 'blue')
unc_1 = np.matrix(betaHat) + np.matrix(np.sqrt(np.diag(sigmaBeta))).T
unc_2 = np.matrix(betaHat) - np.matrix(np.sqrt(np.diag(sigmaBeta))).T
axs[0].plot(unc_1,color = 'grey',linestyle='dashed')
axs[0].plot(unc_2,color = 'grey',linestyle='dashed')
axs[0].set_title("Sparse and Smooth LVLt Regression")

axs[1].plot(hist_omega)
axs[1].set_title("OmegaHat development")
plt.show()

# %% [markdown]
# ## l0 = -1, positive

# %%
l0 = -1
betaHat, sigmaBeta, hist_omega = bayesLVLPositiveRegression(X,y,l0=l0)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(beta_true,color='red',linestyle='dashed')
axs[0].plot(betaHat,color = 'blue')
unc_1 = np.matrix(betaHat) + np.matrix(np.sqrt(np.diag(sigmaBeta))).T
unc_2 = np.matrix(betaHat) - np.matrix(np.sqrt(np.diag(sigmaBeta))).T
axs[0].plot(unc_1,color = 'grey',linestyle='dashed')
axs[0].plot(unc_2,color = 'grey',linestyle='dashed')
axs[0].set_title("Sparse and Smooth LVLt Regression")

axs[1].plot(hist_omega)
axs[1].set_title("OmegaHat development")
plt.show()

# %% [markdown]
# # l0 = 0, positive, to_smooth

# %%
l0 = 0
betaHat, sigmaBeta, hist_omega = bayesLVLPositiveRegression(X,y,l0=l0,to_smooth=True)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(beta_true,color='red',linestyle='dashed')
axs[0].plot(betaHat,color = 'blue')
unc_1 = np.matrix(betaHat) + np.matrix(np.sqrt(np.diag(sigmaBeta))).T
unc_2 = np.matrix(betaHat) - np.matrix(np.sqrt(np.diag(sigmaBeta))).T
axs[0].plot(unc_1,color = 'grey',linestyle='dashed')
axs[0].plot(unc_2,color = 'grey',linestyle='dashed')
axs[0].set_title("Sparse and Smooth LVLt Regression")

axs[1].plot(hist_omega)
axs[1].set_title("OmegaHat development")
plt.show()

# %% [markdown]
# # l0 = -1, positive, to_smooth

# %%
l0 = -1
betaHat, sigmaBeta, hist_omega = bayesLVLPositiveRegression(X,y,l0=l0,to_smooth=True)

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

axs[0].plot(beta_true,color='red',linestyle='dashed')
axs[0].plot(betaHat,color = 'blue')
unc_1 = np.matrix(betaHat) + np.matrix(np.sqrt(np.diag(sigmaBeta))).T
unc_2 = np.matrix(betaHat) - np.matrix(np.sqrt(np.diag(sigmaBeta))).T
axs[0].plot(unc_1,color = 'grey',linestyle='dashed')
axs[0].plot(unc_2,color = 'grey',linestyle='dashed')
axs[0].set_title("Sparse and Smooth LVLt Regression")

axs[1].plot(hist_omega)
axs[1].set_title("OmegaHat development")
plt.show()
